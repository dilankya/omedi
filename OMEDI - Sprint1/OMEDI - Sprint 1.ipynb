# %% [markdown]
# # OMEDI Voice Assistant App

# %% [markdown]
# ## The things that we learned while Sprint-1
#
# #### Working as a group
# #### Sharing jobs equality
# #### Introducing ourselves on a computer language
# #### Make a  model which can recognize words

# %% [markdown]
# ### Step 1: - Speech to text
# Here we will make the first sprint of project. Analyzing song, converting the analyzed sound into words and converting   words to commands. We spereated Speech recognition works in one sub tittle as sprint 1. Now we gonna make a high level speech to text tool. It will analyze accents and words.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### IBM : Speech Analyzer
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Install and Import Dependencies

# %%
# !pip install ibm_watson

# %%
from ibm_watson import SpeechToTextV1
from ibm_watson.websocket import RecognizeCallback, AudioSource 
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %% [markdown]
# ## Setup STT Service

# %%
apikey = 'hcrI9col7TPSZiPNesFzFgA_3Q-r4AUS9XHLlUdQZn3w'
url = 'https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/53636592-9f3a-4e07-9598-36eb12e11bc3'

# %%
# Setup Service
authenticator = IAMAuthenticator(apikey)
stt = SpeechToTextV1(authenticator=authenticator)
stt.set_service_url(url)

# %% [markdown]
# ## Open Source and Convert

# %% [markdown]
# ![image.png](attachment:image.png)
# “There is a pleasure in the pathless woods,
#
# There is a rapture on the lonely shore,
#
# There is society, where none intrudes,
#
# By the deep Sea, and music in its roar:
#
# I love not Man the less, but Nature more,
#
# From these our interviews, in which I steal
#
# From all I may be, or have been before,
#
# To mingle with the Universe, and feel
#
# What I can ne’er express, yet cannot all conceal.”

# %%
# Perform conversion
with open('unknown.mp3', 'rb') as f:
    res = stt.recognize(audio=f, content_type='audio/mp3', model='en-US_NarrowbandModel', continuous=True).get_result()

# %% [markdown]
# There are just few mistake!!

# %%
res
# Out:
# {'result_index': 0,
#  'results': [{'final': True,
#    'alternatives': [{'transcript': "there is a pleasure in the parcels would there is a rapture on the lonely short there is society we're not intrude by the deep sea and music and it's wrong I love not man the less but nature more from these are interviews in which I still from all I may be or have been before to mingle with the universe and feel what I can never express get cannot all conceal ",
#      'confidence': 0.87}]}]}

# %%
text = res['results'][0]['alternatives'][0]['transcript']
text
# Out:
# "there is a pleasure in the password there is a rapture on the lonely Shaw there is a society where not intrude by the deep sea and music in it's raw I love not man the less but nature more from these out interviews in which I still from all I may be all have been before to mingle with the university and feel what I can hear express yeah cannot all concealed "

# %%
confidence = res['results'][0]['alternatives'][0]['confidence']
confidence
# Out:
# 0.78

# %%
with open('output.txt','w') as out:
    out.writelines(text)

# %% [markdown]
# ### Output
# there is a pleasure in the password there is a rapture on the lonely Shaw there is a society where not intrude by the deep sea and music in it's raw I love not man the less but nature more from these out interviews in which I still from all I may be all have been before to mingle with the university and feel what I can hear express yeah cannot all concealed

# %% [markdown]
# ## Play With Language Model

# %%
# Perform conversion
with open('unknown.mp3', 'rb') as f:
    res = stt.recognize(audio=f, content_type='audio/mp3', model='en-AU_NarrowbandModel', continuous=True).get_result()

# %%
res
# Out:
# {'result_index': 0,
#  'results': [{'final': True,
#    'alternatives': [{'transcript': "there is a pleasure in the parcels would there is a rapture on the lonely short there is society we're not intrude by the deep sea and music and it's wrong I love not man the less but nature more from these are interviews in which I still from all I may be or have been before to mingle with the universe and feel what I can never express get cannot all conceal ",
#      'confidence': 0.87}]}]}

# %%
with open('output.txt','w') as out:
    out.writelines(text)
